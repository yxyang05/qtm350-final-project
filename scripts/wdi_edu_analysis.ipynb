# %% [markdown]
# # SQL: Data Cleaning and Analysis

# %%
import sqlite3
import pandas as pd

df = pd.read_csv("../data/wdi_edu_filtered_long.csv")
conn = sqlite3.connect("wdi_edu.db")
df.to_sql("wdi_edu", conn, if_exists="replace", index=False)
# Out:
# 1512

# %%
pd.read_sql('''
SELECT *
FROM wdi_edu
''', conn)
# Out:
#                    region         series  year       value
# 0     East Asia & Pacific        primary  2000  110.224030
# 1     East Asia & Pacific        primary  2001  110.923576
# 2     East Asia & Pacific        primary  2002  109.465172
# 3     East Asia & Pacific        primary  2003  108.066650
# 4     East Asia & Pacific        primary  2004  106.849770
# ...                   ...            ...   ...         ...
# 1507                World  tertiary_male  2016   35.047852
# 1508                World  tertiary_male  2017   35.308880
# 1509                World  tertiary_male  2018   35.517368
# 1510                World  tertiary_male  2019   36.082550
# 1511                World  tertiary_male  2020   37.015572
#
# [1512 rows x 4 columns]

# %% [markdown]
# ## Regional Averages and Distribution of Enrollment (2020-2021)

# %%
pd.read_sql('''
SELECT region, series, AVG(value) AS avg_rate
FROM wdi_edu
WHERE series IN ('primary', 'secondary', 'tertiary')
GROUP BY region, series;
''', conn)
# Out:
#                                                region     series    avg_rate
# 0                                 East Asia & Pacific    primary  104.536424
# 1                                 East Asia & Pacific  secondary   79.326682
# 2                                 East Asia & Pacific   tertiary   32.326086
# 3                               Europe & Central Asia    primary  101.987955
# 4                               Europe & Central Asia  secondary  100.229224
# 5                               Europe & Central Asia   tertiary   61.597396
# 6                           Latin America & Caribbean    primary  110.814036
# 7                           Latin America & Caribbean  secondary   89.990020
# 8                           Latin America & Caribbean   tertiary   40.691914
# 9   Middle East, North Africa, Afghanistan & Pakistan    primary   89.024141
# 10  Middle East, North Africa, Afghanistan & Pakistan  secondary   55.052961
# 11  Middle East, North Africa, Afghanistan & Pakistan   tertiary   21.230170
# 12                                      North America    primary  100.895668
# 13                                      North America  secondary   97.163060
# 14                                      North America   tertiary   82.450066
# 15                                         South Asia    primary  108.019121
# 16                                         South Asia  secondary   62.982683
# 17                                         South Asia   tertiary   18.264229
# 18                                 Sub-Saharan Africa    primary   92.281592
# 19                                 Sub-Saharan Africa  secondary   36.812869
# 20                                 Sub-Saharan Africa   tertiary    7.289573
# 21                                              World    primary  101.293432
# 22                                              World  secondary   69.485886
# 23                                              World   tertiary   29.954535

# %%
pd.read_sql('''
SELECT 
    series,
    AVG(value)  AS mean_rate,
    MIN(value)  AS min_rate,
    MAX(value)  AS max_rate
FROM wdi_edu
WHERE series IN ('primary', 'secondary', 'tertiary')
GROUP BY series;
''', conn)
# Out:
#       series   mean_rate   min_rate    max_rate
# 0    primary  101.106546  79.473808  118.426079
# 1  secondary   73.880423  25.435600  105.108917
# 2   tertiary   36.725496   4.384480   86.950279

# %% [markdown]
# ## Avg Enrollment for Each Education Level per Region

# %%
pd.read_sql('''
WITH growth AS (
    SELECT
        region,
        series,
        AVG(annual_growth) AS avg_growth
    FROM (
        SELECT
            region,
            series,
            value - LAG(value) OVER (PARTITION BY region, series ORDER BY year)
                AS annual_growth
        FROM wdi_edu
        WHERE year BETWEEN 2000 AND 2020
          AND series IN ('primary','secondary','tertiary')
    ) g
    WHERE annual_growth IS NOT NULL
    GROUP BY region, series
)
SELECT
    region,
    MAX(CASE WHEN series = 'primary' THEN avg_growth END) AS primary_growth,
    MAX(CASE WHEN series = 'secondary' THEN avg_growth END) AS secondary_growth,
    MAX(CASE WHEN series = 'tertiary' THEN avg_growth END) AS tertiary_growth
FROM growth
GROUP BY region
ORDER BY region;
''', conn)
# Out:
#                                               region  primary_growth  \
# 0                                East Asia & Pacific       -0.508122
# 1                              Europe & Central Asia       -0.166644
# 2                          Latin America & Caribbean       -0.489661
# 3  Middle East, North Africa, Afghanistan & Pakistan        0.528657
# 4                                      North America       -0.031169
# 5                                         South Asia        0.233246
# 6                                 Sub-Saharan Africa        0.921688
# 7                                              World        0.025631
#
#    secondary_growth  tertiary_growth
# 0          1.387767         1.804751
# 1          0.397700         1.491138
# 2          0.886855         1.552549
# 3          0.525619         0.737428
# 4          0.326427         0.971567
# 5          1.474988         0.949892
# 6          0.963458         0.240672
# 7          0.851748         1.011157

# %% [markdown]
# ## Gap from World Average

# %%
pd.read_sql('''
WITH regional_primary AS (
    SELECT
        region,
        AVG(value) AS avg_primary_rate
    FROM wdi_edu
    WHERE series = 'primary'
      AND region <> 'World'
    GROUP BY region
),
world_primary AS (
    SELECT
        AVG(value) AS world_primary_rate
    FROM wdi_edu
    WHERE series = 'primary'
      AND region = 'World'
)
SELECT
    r.region,
    r.avg_primary_rate,
    w.world_primary_rate,
    (w.world_primary_rate - r.avg_primary_rate) AS gap_from_world
FROM regional_primary r
CROSS JOIN world_primary w;
''', conn)
# Out:
#                                               region  avg_primary_rate  \
# 0                                East Asia & Pacific        104.536424
# 1                              Europe & Central Asia        101.987955
# 2                          Latin America & Caribbean        110.814036
# 3  Middle East, North Africa, Afghanistan & Pakistan         89.024141
# 4                                      North America        100.895668
# 5                                         South Asia        108.019121
# 6                                 Sub-Saharan Africa         92.281592
#
#    world_primary_rate  gap_from_world
# 0          101.293432       -3.242991
# 1          101.293432       -0.694522
# 2          101.293432       -9.520604
# 3          101.293432       12.269291
# 4          101.293432        0.397765
# 5          101.293432       -6.725689
# 6          101.293432        9.011840

# %%
pd.read_sql('''
WITH regional_secondary AS (
    SELECT
        region,
        AVG(value) AS avg_secondary_rate
    FROM wdi_edu
    WHERE series = 'secondary'
      AND region <> 'World'
    GROUP BY region
),
world_secondary AS (
    SELECT
        AVG(value) AS world_secondary_rate
    FROM wdi_edu
    WHERE series = 'secondary'
      AND region = 'World'
)
SELECT
    r.region,
    r.avg_secondary_rate,
    w.world_secondary_rate,
    (w.world_secondary_rate - r.avg_secondary_rate) AS gap_from_world
FROM regional_secondary r
CROSS JOIN world_secondary w;
''', conn)
# Out:
#                                               region  avg_secondary_rate  \
# 0                                East Asia & Pacific           79.326682
# 1                              Europe & Central Asia          100.229224
# 2                          Latin America & Caribbean           89.990020
# 3  Middle East, North Africa, Afghanistan & Pakistan           55.052961
# 4                                      North America           97.163060
# 5                                         South Asia           62.982683
# 6                                 Sub-Saharan Africa           36.812869
#
#    world_secondary_rate  gap_from_world
# 0             69.485886       -9.840796
# 1             69.485886      -30.743338
# 2             69.485886      -20.504134
# 3             69.485886       14.432925
# 4             69.485886      -27.677174
# 5             69.485886        6.503202
# 6             69.485886       32.673017

# %%
pd.read_sql('''
WITH regional_tertiary AS (
    SELECT
        region,
        AVG(value) AS avg_tertiary_rate
    FROM wdi_edu
    WHERE series = 'tertiary'
      AND region <> 'World'
    GROUP BY region
),
world_tertiary AS (
    SELECT
        AVG(value) AS world_tertiary_rate
    FROM wdi_edu
    WHERE series = 'tertiary'
      AND region = 'World'
)
SELECT
    r.region,
    r.avg_tertiary_rate,
    w.world_tertiary_rate,
    (w.world_tertiary_rate - r.avg_tertiary_rate) AS gap_from_world
FROM regional_tertiary r
CROSS JOIN world_tertiary w;
''', conn)
# Out:
#                                               region  avg_tertiary_rate  \
# 0                                East Asia & Pacific          32.326086
# 1                              Europe & Central Asia          61.597396
# 2                          Latin America & Caribbean          40.691914
# 3  Middle East, North Africa, Afghanistan & Pakistan          21.230170
# 4                                      North America          82.450066
# 5                                         South Asia          18.264229
# 6                                 Sub-Saharan Africa           7.289573
#
#    world_tertiary_rate  gap_from_world
# 0            29.954535       -2.371551
# 1            29.954535      -31.642861
# 2            29.954535      -10.737379
# 3            29.954535        8.724365
# 4            29.954535      -52.495531
# 5            29.954535       11.690307
# 6            29.954535       22.664962

# %% [markdown]
# ## Gap with Europe & Central Asia + North America (most developed regions)

# %%
pd.read_sql('''
WITH regional_primary AS (
    SELECT
        region,
        AVG(value) AS avg_primary_rate
    FROM wdi_edu
    WHERE series = 'primary'
      AND region NOT IN ('World', 'Europe & Central Asia', 'North America')
    GROUP BY region
),
benchmark AS (
    SELECT
        AVG(value) AS benchmark_rate
    FROM wdi_edu
    WHERE series = 'primary'
      AND region IN ('Europe & Central Asia', 'North America')
)
SELECT
    r.region,
    r.avg_primary_rate,
    b.benchmark_rate,
    (b.benchmark_rate - r.avg_primary_rate) AS gap_from_benchmark
FROM regional_primary r
CROSS JOIN benchmark b;
''', conn)
# Out:
#                                               region  avg_primary_rate  \
# 0                                East Asia & Pacific        104.536424
# 1                          Latin America & Caribbean        110.814036
# 2  Middle East, North Africa, Afghanistan & Pakistan         89.024141
# 3                                         South Asia        108.019121
# 4                                 Sub-Saharan Africa         92.281592
#
#    benchmark_rate  gap_from_benchmark
# 0      101.441811           -3.094613
# 1      101.441811           -9.372225
# 2      101.441811           12.417670
# 3      101.441811           -6.577310
# 4      101.441811            9.160219

# %%
pd.read_sql('''
WITH regional_secondary AS (
    SELECT
        region,
        AVG(value) AS avg_secondary_rate
    FROM wdi_edu
    WHERE series = 'secondary'
      AND region NOT IN ('World', 'Europe & Central Asia', 'North America')
    GROUP BY region
),
benchmark AS (
    SELECT
        AVG(value) AS benchmark_rate
    FROM wdi_edu
    WHERE series = 'secondary'
      AND region IN ('Europe & Central Asia', 'North America')
)
SELECT
    r.region,
    r.avg_secondary_rate,
    b.benchmark_rate,
    (b.benchmark_rate - r.avg_secondary_rate) AS gap_from_benchmark
FROM regional_secondary r
CROSS JOIN benchmark b;
''', conn)
# Out:
#                                               region  avg_secondary_rate  \
# 0                                East Asia & Pacific           79.326682
# 1                          Latin America & Caribbean           89.990020
# 2  Middle East, North Africa, Afghanistan & Pakistan           55.052961
# 3                                         South Asia           62.982683
# 4                                 Sub-Saharan Africa           36.812869
#
#    benchmark_rate  gap_from_benchmark
# 0       98.696142           19.369460
# 1       98.696142            8.706122
# 2       98.696142           43.643181
# 3       98.696142           35.713458
# 4       98.696142           61.883273

# %%
pd.read_sql('''
WITH regional_tertiary AS (
    SELECT
        region,
        AVG(value) AS avg_tertiary_rate
    FROM wdi_edu
    WHERE series = 'tertiary'
      AND region NOT IN ('World', 'Europe & Central Asia', 'North America')
    GROUP BY region
),
benchmark AS (
    SELECT
        AVG(value) AS benchmark_rate
    FROM wdi_edu
    WHERE series = 'tertiary'
      AND region IN ('Europe & Central Asia', 'North America')
)
SELECT
    r.region,
    r.avg_tertiary_rate,
    b.benchmark_rate,
    (b.benchmark_rate - r.avg_tertiary_rate) AS gap_from_benchmark
FROM regional_tertiary r
CROSS JOIN benchmark b;
''', conn)
# Out:
#                                               region  avg_tertiary_rate  \
# 0                                East Asia & Pacific          32.326086
# 1                          Latin America & Caribbean          40.691914
# 2  Middle East, North Africa, Afghanistan & Pakistan          21.230170
# 3                                         South Asia          18.264229
# 4                                 Sub-Saharan Africa           7.289573
#
#    benchmark_rate  gap_from_benchmark
# 0       72.023731           39.697645
# 1       72.023731           31.331817
# 2       72.023731           50.793561
# 3       72.023731           53.759503
# 4       72.023731           64.734158

# %% [markdown]
# # Average Gender Gaps in Each Education Level (World)

# %%
pd.read_sql('''
WITH male AS (
    SELECT region, year, series, value AS male_rate
    FROM wdi_edu
    WHERE series LIKE '%_male'
),
female AS (
    SELECT region, year, series, value AS female_rate
    FROM wdi_edu
    WHERE series LIKE '%_female'
),
paired AS (
    SELECT
        m.region,
        m.year,
        REPLACE(m.series, '_male', '') AS level,
        m.male_rate,
        f.female_rate,
        m.male_rate - f.female_rate AS gender_gap
    FROM male m
    JOIN female f
      ON m.region = f.region
     AND m.year = f.year
     AND REPLACE(m.series, '_male', '') = REPLACE(f.series, '_female', '')
)
SELECT
    level,
    AVG(male_rate)   AS avg_male_rate,
    AVG(female_rate) AS avg_female_rate,
    AVG(gender_gap)  AS avg_gender_gap
FROM paired
GROUP BY level
ORDER BY level;
''', conn)
# Out:
#        level  avg_male_rate  avg_female_rate  avg_gender_gap
# 0    primary     102.625246        99.523326        3.101920
# 1  secondary      74.752978        72.962301        1.790677
# 2   tertiary      33.892155        39.691699       -5.799544

# %%
pd.read_sql('''
WITH male AS (
    SELECT region, year, series, value AS male_rate
    FROM wdi_edu
    WHERE series LIKE '%_male'
),
female AS (
    SELECT region, year, series, value AS female_rate
    FROM wdi_edu
    WHERE series LIKE '%_female'
),
paired AS (
    SELECT
        m.region,
        REPLACE(m.series, '_male', '') AS level,
        m.male_rate,
        f.female_rate,
        m.male_rate - f.female_rate AS gender_gap
    FROM male m
    JOIN female f
      ON m.region = f.region
     AND m.year = f.year
     AND REPLACE(m.series, '_male', '') = REPLACE(f.series, '_female', '')
)
SELECT
    region,
    level,
    AVG(male_rate)   AS avg_male_rate,
    AVG(female_rate) AS avg_female_rate,
    AVG(gender_gap)  AS avg_gender_gap
FROM paired
GROUP BY region, level
ORDER BY region, level;
''', conn)
# Out:
#                                                region      level  \
# 0                                 East Asia & Pacific    primary
# 1                                 East Asia & Pacific  secondary
# 2                                 East Asia & Pacific   tertiary
# 3                               Europe & Central Asia    primary
# 4                               Europe & Central Asia  secondary
# 5                               Europe & Central Asia   tertiary
# 6                           Latin America & Caribbean    primary
# 7                           Latin America & Caribbean  secondary
# 8                           Latin America & Caribbean   tertiary
# 9   Middle East, North Africa, Afghanistan & Pakistan    primary
# 10  Middle East, North Africa, Afghanistan & Pakistan  secondary
# 11  Middle East, North Africa, Afghanistan & Pakistan   tertiary
# 12                                      North America    primary
# 13                                      North America  secondary
# 14                                      North America   tertiary
# 15                                         South Asia    primary
# 16                                         South Asia  secondary
# 17                                         South Asia   tertiary
# 18                                 Sub-Saharan Africa    primary
# 19                                 Sub-Saharan Africa  secondary
# 20                                 Sub-Saharan Africa   tertiary
# 21                                              World    primary
# 22                                              World  secondary
# 23                                              World   tertiary
#
#     avg_male_rate  avg_female_rate  avg_gender_gap
# 0      104.438934       104.644204       -0.205270
# 1       78.887388        79.819653       -0.932265
# 2       31.243773        33.534001       -2.290228
# 3      102.400096       101.555958        0.844138
# 4      100.954070        99.471357        1.482713
# 5       56.636315        66.740904      -10.104589
# 6      112.137270       109.438046        2.699223
# 7       87.217975        92.848324       -5.630349
# 8       35.859428        45.605031       -9.745603
# 9       94.402242        83.330292       11.071950
# 10      57.982194        51.945064        6.037130
# 11      20.968692        21.511678       -0.542986
# 12     100.973877       100.813888        0.159989
# 13      97.072452        97.259472       -0.187019
# 14      69.590749        95.996241      -26.405493
# 15     107.639706       108.428931       -0.789225
# 16      65.275422        60.509432        4.765989
# 17      19.698693        16.727466        2.971227
# 18      96.213288        88.284099        7.929189
# 19      39.958403        33.621779        6.336624
# 20       8.444231         6.129621        2.314610
# 21     102.796554        99.691188        3.105367
# 22      70.675920        68.223324        2.452597
# 23      28.695361        31.288649       -2.593288
